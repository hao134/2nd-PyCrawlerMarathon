# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11910136549","type":"PushEvent","actor":{"id":57061809,"login":"Black-Spree","display_login":"Black-Spree","gravatar_id":"","url":"https://api.github.com/users/Black-Spree","avatar_url":"https://avatars.githubusercontent.com/u/57061809?"},"repo":{"id":250197528,"name":"Black-Spree/Black-Spree.github.io","url":"https://api.github.com/repos/Black-Spree/Black-Spree.github.io"},"payload":{"push_id":4842785940,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"208af3d392a4eddb80ddb85784510e455cde21bf","before":"8f047e023bc8b4f463f9925e7c038e93ba67e9c0","commits":[{"sha":"208af3d392a4eddb80ddb85784510e455cde21bf","author":{"email":"BlackSpree@outlook.com","name":"Black-Spree"},"message":"update from gridea: 2020-03-31 13:59:43","distinct":true,"url":"https://api.github.com/repos/Black-Spree/Black-Spree.github.io/commits/208af3d392a4eddb80ddb85784510e455cde21bf"}]},"public":true,"created_at":"2020-03-31T06:00:03Z"},{"id":"11910136548","type":"PushEvent","actor":{"id":62411804,"login":"cto300","display_login":"cto300","gravatar_id":"","url":"https://api.github.com/users/cto300","avatar_url":"https://avatars.githubusercontent.com/u/62411804?"},"repo":{"id":251480958,"name":"cto300/table_gan_app","url":"https://api.github.com/repos/cto300/table_gan_app"},"payload":{"push_id":4842785942,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"02e97af273adde19075578ffea02791e7133d57a","before":"27f04e949f604f1126c6eebe563bd2ad09f95d28","commits":[{"sha":"02e97af273adde19075578ffea02791e7133d57a","author":{"email":"62411804+cto300@users.noreply.github.com","name":"cto300"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/cto300/table_gan_app/commits/02e97af273adde19075578ffea02791e7133d57a"}]},"public":true,"created_at":"2020-03-31T06:00:03Z"},{"id":"11910136551","type":"WatchEvent","actor":{"id":5569498,"login":"martiL","display_login":"martiL","gravatar_id":"","url":"https://api.github.com/users/martiL","avatar_url":"https://avatars.githubusercontent.com/u/5569498?"},"repo":{"id":246863090,"name":"PotentialWeb/CoronaTab","url":"https://api.github.com/repos/PotentialWeb/CoronaTab"},"payload":{"action":"started"},"public":true,"created_at":"2020-03-31T06:00:03Z","org":{"id":8987096,"login":"PotentialWeb","gravatar_id":"","url":"https://api.github.com/orgs/PotentialWeb","avatar_url":"https://avatars.githubusercontent.com/u/8987096?"}},{"id":"11910136547","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":247127128,"name":"FredLC/restaurant-fullstack","url":"https://api.github.com/repos/FredLC/restaurant-fullstack"},"payload":{"ref":"dependabot/composer/symfony/http-foundation-5.0.7","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-31T06:00:03Z"},{"id":"11910136540","type":"CreateEvent","actor":{"id":44742666,"login":"BiancaPBM","display_login":"BiancaPBM","gravatar_id":"","url":"https://api.github.com/users/BiancaPBM","avatar_url":"https://avatars.githubusercontent.com/u/44742666?"},"repo":{"id":251513914,"name":"BiancaPBM/Specialization","url":"https://api.github.com/repos/BiancaPBM/Specialization"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-31T06:00:03Z"},{"id":"11910136541","type":"PushEvent","actor":{"id":49162410,"login":"e-com-plus-storefront[bot]","display_login":"e-com-plus-storefront","gravatar_id":"","url":"https://api.github.com/users/e-com-plus-storefront[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49162410?"},"repo":{"id":213725066,"name":"lojatiasonia/emporiotiasonia","url":"https://api.github.com/repos/lojatiasonia/emporiotiasonia"},"payload":{"push_id":4842785939,"size":1,"distinct_s ...

# %%
import json

json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e82ddae-b0fd7a05506df004c1968f39'},
#  'origin': '140.116.91.106',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e82ddd2-12c980d07a9d29204a2441e0'},
#  'origin': '140.116.91.106',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e82ddd4-40af6e3c0018e35c7cb9878c'},
#  'json': None,
#  'origin': '140.116.91.106',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e82ddd7-e6ab0d88aa52353a74b62801'},
#  'json': None,
#  'origin': '140.116.91.106',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
