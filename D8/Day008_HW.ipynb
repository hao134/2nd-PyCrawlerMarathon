# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gt

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>',type(r.text))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ => <class 'str'>

# %%
soup = BeautifulSoup(r.text,'html5lib')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category" property="al:ios:url"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/><link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/><link as="script" href="/_next/static/II-uV6uaXXQC-1C5Hmlm1/pages/forum.js" rel="preload"/><link as="script" href="/_next/static/II-uV6uaXXQC-1C5Hmlm1/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.db2fec09f5a9d8401747.js" rel="preload"/><link as="script" href="/_next/static/chunks/db67c553d07c85ddfb981765661e48883cf9c3a7.db9adb3fe9fc5ee59be2.js" rel="preload"/><link as="script" href="/_next/static/chunks/70f7f72d02c75dc1497edf0520a0eec2d59418b5.e3108cca5f9025da584f.js" rel="preload"/><link as="script" href="/_next/static/chunks/609621a21be2819ec9eccd66fbeb6f70f07f4993.460e67c5c139ce6f0dde.js" rel="preload"/><link as="script" href="/_next/static/chunks/89.777097875375ab8e5dea.js" rel="preload"/><link as="script" href="/_next/static/chunks/a2ae04b7a833ed6fd1ce37130abd264ebd97e830.cf030137604c0cb38f15.js" rel="preload"/><link as="script" href="/_next/static/chunks/164.6c5988f3ed7561beef73.js" rel="preload"/><link as="script" href="/_next/static/chunks/105.a885bf04215ec52ea742.js" rel="preload"/><link as="script" href="/_next/static/chunks/104.b4ff942ee3a3d6b17366.js" rel="preload"/><link as="script" href="/_next/static/chunks/177.603accdf19c278382743.js" rel="preload"/><link as="script" href="/_next/static/chunks/c413fc4a6954ebee2e027383d8ceebc547ef2fde.fc32d38e7bc1bacf8f09.js" rel="preload"/><link as="script" href="/_next/static/chunks/144.26a2aac06e6e32acbf22.js" rel="preload"/><link as="script" href="/_next/static/runtime/webpack-28feb93a9d7551ff4c93.js" rel="preload"/><link as="script" href="/_next/static/chunks/framework.b347b462804689eaf927.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.db2fec09f5a9d8401747.js" rel="preload"/><link as="script" href="/_next/static/chunks/db67c553d07c85ddfb981765661e48883cf9c3a7.db9adb3fe9fc5ee59be2.js" rel="preload"/><link as="script" href="/_next/static/chunks/8d20e4e11f03c19ac09d8da73e67dd9626d9912a.92fb4ba23d99a19d25c7.js" rel="preload"/><link as="script" h ...
# /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: sc-1rm1ozc-0 */
# .homstF{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .homstF img,.homstF svg{height:100%;width:100%;}.bbbsLJ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bbbsLJ img,.bbbsLJ svg{height:100%;width:100%;}.jpXdFc{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jpXdFc img,.jpXdFc svg{height:100%;width:100%;}.drkUgx{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .drkUgx img,.drkUgx svg{height:100%;width:100%;}.bRSgfe{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:21px;height:21px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bRSgfe img,.bRSgfe svg{height:100%;width:100%;}.kfXdDt{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .kfXdDt img,.kfXdDt svg{height:100%;width:100%;}.hCDZLD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hCDZLD img,.hCDZLD svg{height:100%;width:100%;}.gEBqGb{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gEBqGb img,.gEBqGb svg{height:100%;width:100%;}.DkLWL{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .DkLWL img,.DkLWL svg{height:100%;width:100%;}.cdmmlB{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cdmmlB img,.cdmmlB svg{height:100%;width:100%;}.dSfBfZ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .dSfBfZ img,.dSfBfZ svg{height:100%;width:100%;}.cZkFMf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1) ...
# /* sc-component-id: ih5c0o-0 */
# .ktCmNi{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: ih5c0o-2 */
# .ctqwNI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;width:100%;}
# /* sc-component-id: ih5c0o-4 */
# .dsoBbn{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;height:40px;padding:10px 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-size:16px;line-height:normal;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);} .dsoBbn::-webkit-input-placeholder{color:rgba(0,0,0,0.35);} .dsoBbn::-moz-placeholder{color:rgba(0,0,0,0.35);} .dsoBbn:-ms-input-placeholder{color:rgba(0,0,0,0.35);} .dsoBbn::placeholder{color:rgba(0,0,0,0.35);}
# /* sc-component-id: sc-1ehu1w3-0 */
# .bRgdkb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .bRgdkb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.ctrudH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .ctrudH form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#fff;border-radius:6px;overflow:hidden;width:100%;border:solid 1px rgba(0,0,0,0.15);}
# /* sc-component-id: sc-1ehu1w3-1 */
# .CWnzw{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 10px;font-size:14px;color:#fff;} .CWnzw::-webkit-search-cancel-button{position:relative;right:-4px;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:url('/images/search/close-desktop.svg');background-repeat:none;background-position:center;background-size:cover;height:14px;width:14px;} .CWnzw::-webkit-input-placeholder{color:rgba(255,255,255,0.75);} .CWnzw::-moz-placeholder{color:rgba(255,255,255,0.75);} .CWnzw:-ms-input-placeholder{color:rgba(255,255,255,0.75);} .CWnzw::placeholder{color:rgba(255,255,255,0.75);}.goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA::-webkit-search-cancel-button{position:relative;right:-4px;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:url('/images/search/close-mobile.svg');background-repeat:none;background-position:center;background-size:cover;height:18px;width:18px;}
# /* sc-component-id: sc-1ehu1w3-2 */
# .osVsG{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: sc-1ehu1w3-3 */
# .gkunJC{padding-left:6px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ehu1w3-4 */
# .yFCZq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-left:12px;color:rgba(0,0,0,0.5);font-size:16px;font-weight:500;width:50px;}
# /* sc-component-id: sc-1ehu1w3-5 */
# .ioczgP{padding:0 2px;}
# /* sc-component-id: sc-17b0qgb-0 */
# .SRiUL{position:-webkit-sticky;position:sticky;top:0;background:#fff;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}.bseXVK{position:-webkit-sticky;position:sticky;top:0;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}
# /* sc-component-id: sc-17b0qgb-1 */
# .llIPbv{padding:8px 0;}
# /* sc-component-id: sc-17b0qgb-2 */
# .hucDIL{height:28px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-17b0qgb-3 */
# .emtuRP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-17b0qgb-4 */
# .lhBbGS{height:100%;white-space:nowrap;} .lhBbGS:first-child{padding-left:0;} .lhBbGS a{color:#000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .lhBbGS a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.hZDMRR{height:100%;white-space:nowrap;} .hZDMRR:first-child{padding-left:0;} .hZDMRR a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .hZDMRR a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.iFRmnB{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iFRmnB:first-child{padding-left:0;} .iFRmnB a{color:#000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:12px 0px;} .iFRmnB a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.hzsFRq{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .hzsFRq:first-child{padding-left:0;} .hzsFRq a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:12px 0px;} .hzsFRq a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: sc-1erz7nj-0 */
# .tupjO{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:8px;font-size:14px;padding:0 14px;height:36px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .tupjO:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.ilVlFx{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);width:100%;display:block;} .ilVlFx:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .ilVlFx:hover{background:#006aa6;}.ewrJSw{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .ewrJSw:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .ewrJSw:hover{background:#006aa6;}.kbhCcZ{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .kbhCcZ:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.cxZBBR{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:rgba(0,16,32,0.06);color:rgba(0,0,0,0.75);} .cxZBBR:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .cxZBBR:hover{background:#efefef;} .cxZBBR:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.dKseSj{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:transparent;color:#3397cf;padding:0 8px;} .dKseSj:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .dKseSj:active{box-shadow:none;} .dKseSj:hover{color:#006aa6;}.ebSNfi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:none;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,25 ...
# /* sc-component-id: sc-1erz7nj-2 */
# .bNTlZJ> button{border-radius:0;} .bNTlZJ>*:first-child{border-radius:10px 0 0 10px;border-right-width:0;} .bNTlZJ>*:first-child button{border-radius:10px 0 0 10px;border-right-width:0;} .bNTlZJ>*:last-child{border-radius:0 10px 10px 0;border-left-width:0;} .bNTlZJ>*:last-child button{border-radius:0 10px 10px 0;border-left-width:0;}
# /* sc-component-id: dks15x-0 */
# .fWNmIM{position:relative;}
# /* sc-component-id: dks15x-1 */
# .hsNsSw{visibility:hidden;padding-top:calc(100% / 5);pointer-events:none;}.eHdyTY{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}.khJgVN{visibility:hidden;padding-top:calc(100% / 1.5151515151515151);pointer-events:none;}
# /* sc-component-id: dks15x-2 */
# .btKhIn{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: sc-7580fg-0 */
# .hWekac{width:100%;}
# /* sc-component-id: sc-86hs1l-0 */
# .kFcqPk{height:32px;font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,0.75);font-size:13px;border-radius:16px;background:#efefef;padding:0 16px;white-space:nowrap;}.iwYPTt{height:32px;font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,0.75);font-size:14px;border-radius:16px;background:#efefef;padding:0 16px;white-space:nowrap;}
# /* sc-component-id: d14s4-0 */
# .kWuhLO{overflow-y:hidden;}
# /* sc-component-id: d14s4-1 */
# .eWrDFH{overflow-x:auto;overflow-y:hidden;}
# /* sc-component-id: d14s4-2 */
# .fYgReK{white-space:nowrap;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:64px;padding:0 0px;} .fYgReK::after{content:'';-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:64px;width:0px;}
# /* sc-component-id: d14s4-3 */
# .jnFGmH{display:block;}
# /* sc-component-id: d14s4-4 */
# .fGPsmL{display:inline-block;padding-right:16px;padding-top:16px;} .fGPsmL:last-child{padding-right:0;}.fnUokS{display:inline-block;padding-right:8px;padding-top:8px;} .fnUokS:last-child{padding-right:0;}.RpCDL{display:inline-block;padding-right:16px;padding-top:px;} .RpCDL:last-child{padding-right:0;}
# /* sc-component-id: sc-1wz6w4a-0 */
# .jRXqQB{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}.XWDjG{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}
# /* sc-component-id: sc-1hi1x4o-0 */
# .kWVqST{margin:10px 0;}
# /* sc-component-id: sc-4ihej7-0 */
# .cGpUxm{white-space:pre-wrap;}
# /* sc-component-id: sc-6yh43a-0 */
# .lcmPyT{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}.hNXlIX{font-size:18px;line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: fsyoh-0 */
# .kJDOnf{font-weight:500;font-size:24px;line-height:33px;word-wrap:break-word;color:rgba(0,0,0,.95);}.ePUowB{font-weight:500;font-size:28px;line-height:40px;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: sc-405p19-0 */
# .hRbpDK{background:#fff;padding:0 16px 0;}.FSxYW{background:#fff;padding:0 60px 0;}
# /* sc-component-id: sc-405p19-1 */
# .eLVJIY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:5px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.kwWzjf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:0px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-405p19-2 */
# .elTwdm{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-405p19-3 */
# .krNBKU{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}.cGHCFQ{font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}
# /* sc-component-id: sc-405p19-4 */
# .gkJnjG{color:rgba(0,0,0,.35);white-space:nowrap;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;} .gkJnjG:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: sc-405p19-5 */
# .bvalSO{padding:16px 0 24px;}.igiSyv{padding:22px 0 40px;}
# /* sc-component-id: sc-405p19-6 */
# .jKPytA{padding-bottom:24px;}.hKJgyX{padding-bottom:16px;}
# /* sc-component-id: sc-1heqsqc-0 */
# .jtdKe{border-radius:50%;overflow:hidden;}
# /* sc-component-id: sc-1heqsqc-1 */
# .ccflTX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.ezVUnZ{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.joizCB{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.irzYfI{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.kGvIbr{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.dPFFvS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.eyJxfp{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.jfTiSN{background:#cb3a6b;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.bCffFG{background:#2490bf;color:#fff;font-size:20.48px;height:32px;width:32px;line-height:32px;text-align:center;border-radius:50%;}.iJBKht{background:#cb3a6b;color:#fff;font-size:20.48px;height:32px;width:32px;line-height:32px;text-align:center;border-radius:50%;}
# /* sc-component-id: sc-1heqsqc-2 */
# .ilqlpH{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: vt1ivp-0 */
# .eJVCKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:12px;}
# /* sc-component-id: vt1ivp-1 */
# .jPDTQd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:13px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.hhGcWV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:14px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .hhGcWV:hover > *{fill:#ea5c5c;}
# /* sc-component-id: vt1ivp-2 */
# .jtGEVN{cursor:pointer;display:block;margin-right:8px;}.kKpHuw{cursor:pointer;display:block;margin-right:14px;}
# /* sc-component-id: vt1ivp-3 */
# .kRIwhc{background:rgba(0,0,0,0.05);width:1px;height:16px;margin:0 2px 0 10px;}.jdPPuq{background:rgba(0,0,0,0.05);width:1px;height:24px;margin:0 8px 0 16px;}
# /* sc-component-id: sc-1wrppqn-0 */
# .bKjCHy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}.kaIfrV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}
# /* sc-component-id: sc-1wrppqn-1 */
# .ezkBZa{padding-right:15px;}
# /* sc-component-id: sc-1wrppqn-2 */
# .irdkmf{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-3 */
# .fIdNgN{color:rgba(0,0,0,.85);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-4 */
# .emkLLu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;color:rgba(0,0,0,.35);padding-top:3px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-5 */
# .PJors{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1wrppqn-6 */
# .kNUiuk{margin:0 0.5em;border-right:1px solid #dfdfdf;}
# /* sc-component-id: sc-1t5l7uc-0 */
# .cGDMvT{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid transparent;position:relative;}.chpjJz{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid rgb(233,233,233);position:relative;}.blhVoR{color:rgba(0,0,0,.85);font-size:18px;padding:26px 30px;border-bottom:1px solid transparent;position:relative;}.jLZYil{color:rgba(0,0,0,.85);font-size:18px;padding:26px 20px;border-bottom:1px solid transparent;position:relative;}
# /* sc-component-id: sc-1t5l7uc-1 */
# .iuZiCA{margin-top:20px;padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1t5l7uc-2 */
# .gPZLIV{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}.NdBvW{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}
# /* sc-component-id: sc-1t5l7uc-3 */
# .fbtLVK{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .fbtLVK .sc-1g05ju-0 > img{height:25vh;}.cxftkp{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .cxftkp .sc-1g05ju-0 > img{height:25vh;}.kzQRFP{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .kzQRFP .sc-1g05ju-0 > img{height:initial;}.kogmmG{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .kogmmG .sc-1g05ju-0 > img{height:initial;}
# /* sc-component-id: sc-1jf3ag7-0 */
# .dKRAFa{padding:0 16px;}.bYxfmO{padding:0 60px;}
# /* sc-component-id: sc-1jf3ag7-1 */
# .iIxzGL{border-bottom:1px solid rgba(0,0,0,0.05);padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;font-weight:400;}.fBhzEe{border-bottom:1px solid rgb(233,233,233);padding:2px 0;color:rgba(0,0,0,.35);font-size:16px;font-weight:400;}
# /* sc-component-id: nxot29-0 */
# .dBpdSw{padding:0 16px;}.iYpwSB{padding:0 60px;}
# /* sc-component-id: nxot29-1 */
# .gxgEFV{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;border-bottom:1px solid rgb(233,233,233);}.emUyao{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: ku7hkd-0 */
# .cjrmwT{background:#f5f5f5;padding:0 60px;padding-bottom:120px;}
# /* sc-component-id: ku7hkd-1 */
# .dqhhnS{border-top:1px solid rgb(233,233,233);padding:24px 0;}.eEtwtF{border-top:1px solid transparent;padding:24px 0;}
# /* sc-component-id: ku7hkd-2 */
# .eXJZdk{background:#fff;color:rgba(0,0,0,.35);border-radius:4px;border:1px solid rgb(233,233,233);line-height:60px;font-size:18px;padding-left:17px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:text;}
# /* sc-component-id: sc-8n4pv8-0 */
# .fOXphs{position:relative;height:120px;padding:16px 0;width:100%;}.dxHwn{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: olnp72-0 */
# .dddAwk{background:#edad1d;color:#fff;padding:14px 0;font-size:14px;text-align:center;}.hmMOjU{background:#EA5C5C;color:#fff;padding:14px 0;font-size:14px;text-align:center;}
# /* sc-component-id: olnp72-1 */
# .jUDRHq{padding:16px 16px;}.gbDaxp{padding:22px 60px;}
# /* sc-component-id: olnp72-2 */
# .hXEXYl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: olnp72-3 */
# .fqicHK{padding-right:15px;}
# /* sc-component-id: olnp72-5 */
# .egoBgt{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: olnp72-6 */
# .hlWhQH{font-size:13px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}.KGljv{font-size:16px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: olnp72-9 */
# .dRQLtg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:22px;}
# /* sc-component-id: olnp72-10 */
# .iqmXir{background:#edad1d;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}.cHSadV{background:#EA5C5C;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}.hBNlGU{background:#edad1d;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}.hVnPOC{background:#a3a3a3;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}.hzndmu{background:#EA5C5C;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}.jyDxSd{background:#a3a3a3;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}
# /* sc-component-id: sc-1kuvyve-0 */
# .HPJWH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}.fDYFAm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;pointer-events:none;}
# /* sc-component-id: sc-1kuvyve-1 */
# .cYcyMQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.ifcbUA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}
# /* sc-component-id: sc-1kuvyve-2 */
# .nArqW{display:block;height:21px;width:21px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .nArqW:first-child{margin-left:0;}.kmYity{display:block;height:24px;width:24px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .kmYity:first-child{margin-left:0;}.cdwOPp{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .cdwOPp:first-child{margin-left:0;}
# /* sc-component-id: sc-1kuvyve-3 */
# .ejolKO{padding-left:6px;}
# /* sc-component-id: sc-13t0dac-0 */
# .gglUe{padding:0 16px;background:#fff;}.aZFvE{padding:0 60px;background:#fff;}
# /* sc-component-id: sc-13t0dac-1 */
# .bUZMTr{padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-top:1px solid rgba(0,0,0,0.05);border-bottom:1px solid rgba(0,0,0,0.05);}.lhzXMC{padding:6px 0;color:rgba(0,0,0,.35);font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-13t0dac-2 */
# .jueEHw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-13t0dac-3 */
# .cGIYVA{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}
# /* sc-component-id: sc-13t0dac-4 */
# .gYwJjF span{border-color:#fff;}
# /* sc-component-id: sc-1qqve8m-0 */
# .illTCe{color:rgba(0,0,0,.35);}.bdkwEy{color:rgba(0,0,0,.35);padding:40px 0;}
# /* sc-component-id: sc-1qqve8m-1 */
# .XeqfP{display:grid;grid-template-columns:repeat(1,1fr);grid-gap:0 8px;margin-top:0px;padding:0 16px;}.iyxdng{display:grid;grid-template-columns:repeat(2,1fr);grid-gap:0 8px;margin-top:10px;padding:0 60px;}
# /* sc-component-id: sc-1qqve8m-2 */
# .cuKSrd{position:relative;min-width:0;border-bottom:1px solid rgba(0,0,0,0.05);} .cuKSrd:last-child{border-bottom:none;} .cuKSrd a{color:rgba(0,0,0,.85);font-size:15px;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:16px 0 16px 23px;} .cuKSrd a:hover{color:#797979;} .cuKSrd a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}.cGkAqu{position:relative;min-width:0;} .cGkAqu:last-child{border-bottom:none;} .cGkAqu a{color:rgba(0,0,0,.85);font-size:16px;font-weight:bold;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:8px 0 8px 18px;} .cGkAqu a:hover{color:#797979;} .cGkAqu a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}
# /* sc-component-id: nruxq1-0 */
# .eTDfPn{position:relative;}
# /* sc-component-id: nruxq1-1 */
# .grnwFb{position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);height:300vh;visibility:hidden;pointer-events:none;}
# /* sc-component-id: wve5t5-0 */
# .iyEiZp{border-radius:4px;min-height:100%;width:100%;padding:8px 0;}.hVmjyp{border-radius:4px;min-height:100%;width:100%;}
# /* sc-component-id: wve5t5-1 */
# .faUfSV{padding:0px 0 0px;margin-top:0px;background:#fff;} .faUfSV:before{display:block;background:rgba(0,0,0,0.05);content:'';height:1px;width:calc(100% - 32px);margin:0 16px;}.kukIgj{padding:0px 0 0px;margin-top:8px;background:#fff;}.ijHiVA{padding:0px 0 0px;margin-top:0px;background:#fff;}.bJEuXb{padding:0px 0 0px;margin-top:0px;}.gLHwef{padding:16px 0 16px;margin-top:0px;}
# /* sc-component-id: wve5t5-2 */
# .hxGFYN{padding:0px 0 0px;margin-top:8px;background:#fff;background:#fff;}.jpQmJL{padding:60px 0 36px;margin-top:0px;background:#f5f5f5;}
# /* sc-component-id: wve5t5-3 */
# .eqnpDL{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;}.geqEAh{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: wve5t5-4 */
# .lbUsFo{padding-bottom:50px;}.dSoULN{padding-bottom:px;}
# /* sc-component-id: wve5t5-5 */
# .kZVGHl{padding:22px 16px;}.hngKpu{padding:22px 60px;}
# /* sc-component-id: wve5t5-6 */
# .jpaRaL{padding-bottom:120px;}
# /* sc-component-id: sc-1frbu9m-0 */
# .gAIWvd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;padding:50px 0;}
# /* sc-component-id: sc-1frbu9m-1 */
# .efhfxs{display:block;width:250px;margin-bottom:30px;}
# /* sc-component-id: sc-1frbu9m-2 */
# .crcRQC{font-size:30px;font-weight:400;line-height:42px;margin-bottom:10px;}
# /* sc-component-id: sc-1frbu9m-3 */
# .gEjHwc{color:rgba(0,0,0,.45);font-size:18px;line-height:30px;max-width:45%;}
# /* sc-component-id: sc-1jgvchl-0 */
# .hGKgGu{min-height:calc(100vh - 48px);height:100%;}
# /* sc-component-id: sc-1szhyqg-0 */
# .fizRcc{display:grid;max-width:1280px;margin:auto;padding:60px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}
# /* sc-component-id: sc-1szhyqg-1 */
# .bFQTAq{grid-column:start / mainLeft;}
# /* sc-component-id: sc-1szhyqg-2 */
# .cBkHYU{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}
# /* sc-component-id: sc-1szhyqg-3 */
# .iGPfkn{grid-column:mainRight / end;}
# /* sc-component-id: sc-9fdzn5-0 */
# .eeGzXR{margin:0 12px;min-height:calc(100vh - 80px);min-width:728px;padding-top:20px;height:100%;}
# /* sc-component-id: sc-9fdzn5-1 */
# .eQohHX{height:100%;background:#fff;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-17x0g9b-0 */
# .ldlYQO{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;padding:0 12px;}.geHAXF{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}.blXIQQ{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}
# /* sc-component-id: sc-17x0g9b-1 */
# .iFfAVt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}
# /* sc-component-id: sc-1lftjqb-0 */
# .ioHIdq{margin-right:16px;}
# /* sc-component-id: ezgous-0 */
# .ktvxUR{display:block;height:100%;}
# /* sc-component-id: sc-1h3w01r-0 */
# .kElwiP{height:100%;padding:10px 0;display:block;}.BYkrm{height:100%;padding:16px 0;display:block;}
# /* sc-component-id: sc-1ccznvc-0 */
# .bTbYIC{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ccznvc-1 */
# .dacFof{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ccznvc-2 */
# .btyxdF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}
# /* sc-component-id: sc-1xoh8vd-0 */
# .eQqQOc{height:48px;width:100%;background:#006aa6;}
# /* sc-component-id: sc-1xoh8vd-1 */
# .eBbPuw{max-width:px;height:100%;margin:auto;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:4px;}
# /* sc-component-id: p0732u-2 */
# .hOBRZF{display:inline-block;height:100%;}
# /* sc-component-id: sc-18hjmuk-0 */
# .gaeSlb{position:fixed;top:0;z-index:11;height:60px;width:100%;background:#006aa6;}
# /* sc-component-id: sc-18hjmuk-1 */
# .gEMehv{padding:0 20px;max-width:432px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1f7f012-0 */
# .kZdsBL{height:76px;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;border-bottom:1px solid rgba(0,0,0,0.15);background-color:#fff;}
# /* sc-component-id: sc-1f7f012-1 */
# .VoRSe{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1f7f012-2 */
# .sfCyH{width:44px;height:44px;}
# /* sc-component-id: sc-1f7f012-3 */
# .deRddy{margin-left:16px;}
# /* sc-component-id: sc-1f7f012-4 */
# .gNeIRi{margin:0;color:rgba(0,0,0,0.75);font-size:17px;}
# /* sc-component-id: sc-1f7f012-5 */
# .hsZPUX{margin:8px 0 0;color:rgba(0,0,0,0.5);font-size:13px;}
# /* sc-component-id: sc-1az4f7f-0 */
# .eGHpfO{display:block;border-radius:50%;object-fit:cover;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;overflow:hidden;}
# /* sc-component-id: sc-158tams-0 */
# .dSrvo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-158tams-1 */
# .lmkrgH{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-158tams-2 */
# .cpBbLD{position:relative;height:auto;-webkit-transition:height 0.3s cubic-bezier(.4,0,.2,1);transition:height 0.3s cubic-bezier(.4,0,.2,1);overflow:hidden;}
# /* sc-component-id: sc-158tams-3 */
# ...
# .eDFFbM{display:block;position:absolute;top:0;left:0;-webkit-transform-origin:bottom;-ms-transform-origin:bottom;transform-origin:bottom;height:100%;}
# /* sc-component-id: sc-1eyrgkf-0 */
# .bjVPjd{background:#fff;border-radius:10px;padding:36px 0 20px;text-align:center;}.mCkuE{background:#fff;border-radius:0px;padding:36px 0 0;text-align:center;}
# /* sc-component-id: sc-1eyrgkf-1 */
# .fRlXRb{width:500px;}
# /* sc-component-id: sc-1eyrgkf-2 */
# .cHeJUb{max-width:300px;margin:auto;margin-bottom:40px;pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.eYCxWh{max-width:300px;margin:auto;margin-bottom:20px;pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: sc-1eyrgkf-3 */
# .dbdxu{color:rgba(0,0,0,.85);font-size:24px;font-weight:500;margin-bottom:10px;}.idLQyI{color:rgba(0,0,0,.85);font-size:21px;font-weight:500;margin-bottom:10px;}
# /* sc-component-id: sc-1eyrgkf-4 */
# .krJiBc{font-size:18px;color:rgba(0,0,0,.6);line-height:1.6;}.bwzCjg{font-size:16px;color:rgba(0,0,0,.6);line-height:1.6;}
# /* sc-component-id: sc-1eyrgkf-5 */
# .laPWdL{margin-top:20px;}
# /* sc-component-id: sc-1eyrgkf-6 */
# .giihJS{display:block;margin:0 auto 10px;width:150px;}.dCSokb{display:block;margin:0 auto 10px;width:100%;}
# /* sc-component-id: sc-keyframes-iPJGGt */
# @-webkit-keyframes iPJGGt{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.25deg);-ms-transform:rotate(1.25deg);transform:rotate(1.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes iPJGGt{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.25deg);-ms-transform:rotate(1.25deg);transform:rotate(1.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-kNFDXI */
# @-webkit-keyframes kNFDXI{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.25deg);-ms-transform:rotate(-1.25deg);transform:rotate(-1.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes kNFDXI{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.25deg);-ms-transform:rotate(-1.25deg);transform:rotate(-1.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-RMwUL */
# @-webkit-keyframes RMwUL{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-2.25deg);-ms-transform:rotate(-2.25deg);transform:rotate(-2.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes RMwUL{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-2.25deg);-ms-transform:rotate(-2.25deg);transform:rotate(-2.25deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-MVWtb */
# @-webkit-keyframes MVWtb{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.75deg);-ms-transform:rotate(1.75deg);transform:rotate(1.75deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes MVWtb{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.75deg);-ms-transform:rotate(1.75deg);transform:rotate(1.75deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-cwtlmZ */
# @-webkit-keyframes cwtlmZ{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.55deg);-ms-transform:rotate(-1.55deg);transform:rotate(-1.55deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes cwtlmZ{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.55deg);-ms-transform:rotate(-1.55deg);transform:rotate(-1.55deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-hBlQch */
# @-webkit-keyframes hBlQch{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.35deg);-ms-transform:rotate(1.35deg);transform:rotate(1.35deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes hBlQch{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(1.35deg);-ms-transform:rotate(1.35deg);transform:rotate(1.35deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: sc-keyframes-gDAchB */
# @-webkit-keyframes gDAchB{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.45deg);-ms-transform:rotate(-1.45deg);transform:rotate(-1.45deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}} @keyframes gDAchB{0%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}80%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}90%{-webkit-transform:rotate(-1.45deg);-ms-transform:rotate(-1.45deg);transform:rotate(-1.45deg);}100%{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);}}
# /* sc-component-id: vvcosu-0 */
# .eXDWna{width:100%;height:100%;-webkit-perspective:1200px;-moz-perspective:1200px;-ms-perspective:1200px;perspective:1200px;}
# /* sc-component-id: vvcosu-1 */
# .dZXqMz{width:100%;height:100%;-webkit-transform-style:preserve-3d;-ms-transform-style:preserve-3d;transform-style:preserve-3d;}
# /* sc-component-id: zpa1f6-0 */
# .apoP{position:relative;width:100%;-webkit-transform-style:preserve-3d;-ms-transform-style:preserve-3d;transform-style:preserve-3d;}
# /* sc-component-id: zpa1f6-1 */
# .bWOeJC{position:absolute;white-space:nowrap;height:100%;width:100%;top:0;}
# /* sc-component-id: sc-11fjicw-0 */
# .iFroCv{position:absolute;top:0;right:0;left:0;bottom:0;-webkit-transform-style:preserve-3d;-ms-transform-style:preserve-3d;transform-style:preserve-3d;z-index:0;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;font-size:153px;} @media screen and (max-width:540px){.iFroCv{font-size:26.5vw;}}
# /* sc-component-id: sc-11fjicw-1 */
# .gKgugA{background-color:#bc8900;border-radius:0.15em;-webkit-transform:translateZ(-2px);-ms-transform:translateZ(-2px);transform:translateZ(-2px);position:absolute;top:0;right:0;left:0;bottom:0;}
# /* sc-component-id: sc-11fjicw-2 */
# .bvWIoH{border-radius:0.15em;background-image:linear-gradient( 120deg,rgba(188,137,0,0) 30%,rgba(255,255,255,1) 50%,rgba(188,137,0,0) 70% );background-repeat:no-repeat;position:absolute;top:0;right:0;left:0;bottom:0;}
# /* sc-component-id: sc-11fjicw-3 */
# .eVRwjV{position:absolute;top:0.06em;right:0.06em;left:0.06em;bottom:0.06em;border-radius:calc(0.15em - 0.06em + 1px);background-repeat:no-repeat;-webkit-transform-style:preserve-3d;-ms-transform-style:preserve-3d;transform-style:preserve-3d;background-color:#ffffff;} .eVRwjV:before{content:'';position:absolute;left:3px;top:3px;right:3px;bottom:3px;border:1px dotted #bc8900;border-radius:calc(0.15em - 0.06em - 2px);}
# /* sc-component-id: sc-11fjicw-4 */
# .fFPjZD{position:absolute;top:0;right:0;left:0;bottom:0;-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}
# /* sc-component-id: sc-11fjicw-5 */
# .ZpfQh{position:absolute;top:0;right:0;left:0;bottom:0;}
# /* sc-component-id: sc-11fjicw-6 */
# .fAOwnn{position:absolute;top:0;right:0;left:0;bottom:0;z-index:99;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#b38700;padding:0.1em;text-align:center;text-overflow:clip;} .fAOwnn:before{content:'';position:absolute;left:1px;top:1px;right:1px;bottom:1px;border:1px solid #bc8900;border-radius:calc(0.15em - 0.06em);} .fAOwnn:after{content:'';position:absolute;left:3px;top:3px;right:3px;bottom:3px;border:1px dotted #bc8900;border-radius:calc(0.15em - 0.06em - 2px);}
# /* sc-component-id: sc-11fjicw-7 */
# .jZOVOY{width:0.3em;height:0.3em;margin:0.08em;}
# /* sc-component-id: sc-11fjicw-8 */
# .fcFtzX{font-size:0.14em;font-weight:normal;line-height:1.6;}
# /* sc-component-id: sc-11fjicw-9 */
# .hnhJmK{font-size:0.24em;line-height:1.4;font-weight:600;}
# /* sc-component-id: sc-11fjicw-10 */
# .fkxjjp{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.02em;}
# /* sc-component-id: sc-11fjicw-11 */
# .bfnwry{font-size:0.12em;}
# /* sc-component-id: sc-11fjicw-12 */
# .kePTyJ{width:0.15em;height:0.02em;margin:0.03em;background-color:#b38700;}
# /* sc-component-id: sc-11fjicw-13 */
# .hbfDmi{font-size:0.12em;}
# /* sc-component-id: sc-global-2313391383 */
# body{overflow-y:auto;}
# /* sc-component-id: sc-1rqgagn-0 */
# .jjtlvm{position:fixed;overflow:hidden;left:0;top:0;bottom:0;right:0;background-image:url('/images/fastpass/bg_pattern_blue.svg');background-color:#00324e;background-size:160pt;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:center;max-height:100vh;font-size:139px;} @media screen and (max-width:540px){.jjtlvm{font-size:24vw;}}
# /* sc-component-id: sc-1rqgagn-2 */
# .gFMZPZ{width:80vmin;max-width:463.5px;}
# /* sc-component-id: sc-1rqgagn-3 */
# .gkZTxe{margin:0.48em 0 0.18em;font-weight:bold;font-weight:600;}
# /* sc-component-id: sc-1rqgagn-4 */
# .fOUrsd{color:#fff;font-size:0.18em;line-height:1.15;}
# /* sc-component-id: sc-1rqgagn-5 */
# .hgtPvF{color:#efad1d;font-size:0.24em;margin:0.67em 0;line-height:1.15;}
# /* sc-component-id: sc-1rqgagn-6 */
# .euCwHx{margin:0.48em 0 0.08em;} .euCwHx a{margin:0.08em;} .euCwHx a:first-child{margin-left:0;} .euCwHx img{width:1.22em;height:0.4em;}
# /* sc-component-id: sc-1rqgagn-7 */
# .iPwtfe{text-align:center;font-size:0.12em;color:rgba(255,255,255,0.9);}</style></head><body><div id="__next"><div class="sc-18hjmuk-0 gaeSlb"><div class="sc-1ccznvc-0 bTbYIC"><div class="sc-1ccznvc-1 dacFof"><a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a><div class="sc-18hjmuk-1 gEMehv"><div class="sc-1ehu1w3-0 bRgdkb"><form><label class="ih5c0o-0 ktCmNi"><div class="ih5c0o-2 ctqwNI"><input aria-label="搜尋" class="ih5c0o-4 dsoBbn sc-1ehu1w3-1 CWnzw" placeholder="搜尋" type="search" value=""/></div></label><button class="sc-1ehu1w3-2 osVsG" disabled="" title="搜尋" type="submit"><span class="sc-1rm1ozc-0 hCDZLD sc-1ehu1w3-6 flgHFG" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button></form></div></div></div><div class="sc-1ccznvc-2 btyxdF" role="navigation"><a class="sc-17x0g9b-0 geHAXF" href="/signup?redirect=%2Ff" role="button"><span class="sc-17x0g9b-1 iFfAVt">登入</span></a><div class="p0732u-2 hOBRZF"><a class="sc-17x0g9b-0 blXIQQ" role="button" title="更多"><span class="sc-17x0g9b-1 iFfAVt"><span class="sc-1rm1ozc-0 gEBqGb sc-17x0g9b-2 bGGVPx" fill="#fff" role="img" size="26"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="sc-1szhyqg-0 fizRcc"><div class="sc-1szhyqg-1 bFQTAq"><div class="sc-1xg2zzw-0 PiZcj"><a href="/forum/all"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc sc-1xg2zzw-2 eMXSfJ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="sc-1x63gba-1 eFYrsX">所有看板</div></div></a><a href="/forum/popular"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc sc-1xg2zzw-2 eMXSfJ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="sc-1x63gba-1 eFYrsX">即時熱門看板</div></div></a><a href="/goods"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc gpcsqh-0 hRuOXd" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M8 21a2 2 0 11-2-2 2 2 0 012 2zm10-2a2 2 0 102 2 2 2 0 00-2-2zm2.44-1.19v-1a.5.5 0 00-.5-.5H6.3a.5.5 0 01-.4-.81L7.05 14a1 1 0 00.16-.93L4.48 4.72A1 1 0 004 4.13l-1.85-.9a.5.5 0 00-.67.23l-.48.9a.51.51 0 00.24.64l1.47.71 2.43 7.48-.82 1a2.49 2.49 0 00-.09 2.94 2.62 2.62 0 002.2 1.1h13.5a.51.51 0 00.5-.42zm1.35-7V6.38a2 2 0 00-2-2H9.23A2 2 0 007.3 6.92l1.82 5.8a2 2 0 002.3 1.43l8.74-1.33a2 2 0 001.62-1.97z"></path></svg></span></div><div class="sc-1x63gba-1 eFYrsX">好物研究室</div></div></a><div class="sc-4rlo ...

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ',type(soup))

'''
Your Code Here
'''
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>  <class 'bs4.BeautifulSoup'>
# '\nYour Code Here\n'

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

header = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Mobile Safari/537.36'}
r = requests.get(url,headers = header)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
import requests
url = 'https://www.zhihu.com/explore'

header = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Mobile Safari/537.36'}
r = requests.get(url,headers = header)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-ZA-Experiment" content="default:None">
# <title>发现 - 知乎</title>
#
# <meta name="apple-itunes-app" content="app-id=432274380, app-argument=zhihu://explore">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>
# <meta http-equiv="mobile-agent" content="format=html5;url=https://www.zhihu.com/explore">
# <meta id="znonce" name="znonce" content="6ffaedfafb71404bb82e28ab03c95ae6">
#
#
#
# <link rel="apple-touch-icon" href="https://static.zhihu.com/s

# %%
url = 'https://www.zhihu.com/explore'

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6,ja;q=0.5',
    'cache-control': 'max-age=0',
    'cookie': '_zap=a5634a47-a806-4828-8ab4-2cbc03734bda; d_c0="AFBoGjc1fg6PTus2_H76YgMM3xvztVHRnCs=|1541767835"; __gads=ID=18e1196642fc5994:T=1544975081:S=ALNI_MZ2lQjiLHPlLxjVqGGH6o-EiL2luQ; z_c0="2|1:0|10:1551204934|4:z_c0|92:Mi4xM1FkMERnQUFBQUFBVUdnYU56Vi1EaVlBQUFCZ0FsVk5SdEJpWFFDUXZ6REVHVWw0QWtXblh6WGt4T183ekdxNFhn|fa542d11758c34207cdd6a1edf85de768ac02624c8cb53aa687017af49accd7b"; tst=r; q_c1=aed50b9b158344d6ac78a230c8970d83|1560948516000|1543510922000; __utmv=51854390.100--|2=registration_date=20190226=1^3=entry_date=20181130=1; _xsrf=13cd498d-6139-4c50-99a6-df5c749dd64c; tgw_l7_route=4860b599c6644634a0abcd4d10d37251; __utma=51854390.567487929.1560948518.1560950333.1562469680.3; __utmb=51854390.0.10.1562469680; __utmc=51854390; __utmz=51854390.1562469680.3.3.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/notebooks/day2-example.ipynb',
    'referer': 'http://localhost:8888/notebooks/day2-example.ipynb',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
}
r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的

# %%
url = 'https://www.zhihu.com/explore'

headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6,ja;q=0.5',
    'cache-control': 'max-age=0',
    'cookie': '_zap=a5634a47-a806-4828-8ab4-2cbc03734bda; d_c0="AFBoGjc1fg6PTus2_H76YgMM3xvztVHRnCs=|1541767835"; __gads=ID=18e1196642fc5994:T=1544975081:S=ALNI_MZ2lQjiLHPlLxjVqGGH6o-EiL2luQ; z_c0="2|1:0|10:1551204934|4:z_c0|92:Mi4xM1FkMERnQUFBQUFBVUdnYU56Vi1EaVlBQUFCZ0FsVk5SdEJpWFFDUXZ6REVHVWw0QWtXblh6WGt4T183ekdxNFhn|fa542d11758c34207cdd6a1edf85de768ac02624c8cb53aa687017af49accd7b"; tst=r; q_c1=aed50b9b158344d6ac78a230c8970d83|1560948516000|1543510922000; __utmv=51854390.100--|2=registration_date=20190226=1^3=entry_date=20181130=1; _xsrf=13cd498d-6139-4c50-99a6-df5c749dd64c; tgw_l7_route=4860b599c6644634a0abcd4d10d37251; __utma=51854390.567487929.1560948518.1560950333.1562469680.3; __utmb=51854390.0.10.1562469680; __utmc=51854390; __utmz=51854390.1562469680.3.3.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/notebooks/day2-example.ipynb',
    'referer': 'https://www.zhihu.com/explore',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Mobile Safari/537.36'
}
r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-ZA-Experiment" content="default:None">
# <title>发现 - 知乎</title>
#
# <meta name="apple-itunes-app" content="app-id=432274380, app-argument=zhihu://explore">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>
# <meta http-equiv="mobile-agent" content="format=html5;url=https://www.zhihu.com/explore">
# <meta id="znonce" name="znonce" content="002b3cc86e554d4b8bae83bcee648712">
#
#
#
# <link rel="apple-touch-icon" href="https://static.zhihu.com/s
