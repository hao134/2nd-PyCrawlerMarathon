jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/1b868f49-60f7-454d-87d9-7fb13ded53a2","thumbnail":"https://megapx-assets.dcard.tw/images/1b868f49-60f7-454d-87d9-7fb13ded53a2/160.jpeg","type":"image/megapx","tags":[],"createdAt":"2020-03-31T02:44:48.850Z","updatedAt":"2020-03-31T02:44:48.850Z","width":890,"height":1188},{"id":"03e71523-b8f9-420c-ab5f-d8799a149232","url":"https://megapx-assets.dcard.tw/images/fd619c94-66df-4d4e-aa3e-c3575e31190a/640.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/fd619c94-66df-4d4e-aa3e-c3575e31190a","thumbnail":"https://megapx-assets.dcard.tw/images/fd619c94-66df-4d4e-aa3e-c3575e31190a/160.jpeg","type":"image/megapx","tags":[],"createdAt":"2020-03-31T02:44:48.850Z","updatedAt":"2020-03-31T02:44:48.850Z","width":1108,"height":1478},{"id":"551ab75a-56e3-41eb-a1a7-4953bb46abe2","url":"https://megapx-assets.dcard.tw/images/017da3d8-d036-4679-b50e-1c0b126d71fc/640.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/017da3d8-d036-4679-b50e-1c0b126d71fc","thumbnail":"https://megapx-assets.dcard.tw/images/017da3d8-d036-4679-b50e-1c0b126d71fc/160.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-03-31T02:04:57.235Z","updatedAt":"2020-03-31T02:44:48.850Z","width":2000,"height":1500}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":340},{"id":"e8e6bc5d-41b0-4129-b ...

# %%
import json
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 農柴特攻隊🐶
# 我家貓咪換掉誠品臉書大頭貼了
# 被騙一秒負責一生❤️🐰
# 最帥柴柴
# 小胖鼠丸丸
# 誰家的黑柴不見啦
# 中原大學走失的柴柴
# #曬貓 連睡覺都要吃的胖橘
# 通緝這隻可愛的貓貓
# 胖子一枚
# #圖 這是何等生物？
# 論博美的崩壞（？！
# 各位覺得該不該開水族版
# 貓愛咬人
# 我家的貓喝魚缸的水
# 家裡兔子的動作影片集
# 我只有三隻腳 但是跑很快喔Part.2
# 隨時防疫的貓🐱
# #柯基#米糕
# 尋虎斑小貓貓之家🐱
# 各位我想問一個問題
# 母狗結紮 肚子好像怪怪的.....
# 無聊曬個柴🐶療癒一波
# 隱身術ㄇ？
# 秉持胖子黃金法則的吉
# 有需求才有設計
# 喜歡被夾扁
# 黃金鼠炸毛
# 問 獸醫 眼科
# 瑪丁無穀鴨肉貓飼料中有金屬物品

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#     2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
#     3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
